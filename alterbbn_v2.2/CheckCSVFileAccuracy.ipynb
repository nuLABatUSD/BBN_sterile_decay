# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import BeginnersGraphs as ev

# %% [markdown]
# ## a's

# %%
df_a_np = pd.read_csv("CSV Files/a_np.csv", names=["index", "output"], index_col=False, usecols = ["output"])
df_a_np_hannah = pd.read_csv("300-7e-05-FullTestNew/mass_300_mix_7e-05_a_np.csv", names=["index", "output"], index_col=False, usecols = ["output"])

fig = plt.figure()

for frame in [df_a_np, df_a_np_hannah]:
    plt.plot(frame.index, frame['output'])

plt.show()

# %%
df_a_pn = pd.read_csv("CSV Files/a_pn.csv", names=["index", "output"], index_col=False, usecols = ["output"])
df_a_pn_hannah = pd.read_csv("300-7e-05-FullTestNew/mass_300_mix_7e-05_a_pn.csv", names=["index", "output"], index_col=False, usecols = ["output"])

fig = plt.figure()

for frame in [df_a_pn, df_a_pn_hannah]:
    plt.plot(frame.index, frame['output'])

plt.show()

# %%
df_a_rhonu = pd.read_csv("CSV Files/a_rhonu.csv", names=["index", "output"], index_col=False, usecols = ["output"])
df_a_rhonu_hannah = pd.read_csv("300-7e-05-FullTestNew/mass_300_mix_7e-05_a_rhonu.csv", names=["index", "output"], index_col=False, usecols = ["output"])

fig = plt.figure()

for frame in [df_a_rhonu, df_a_rhonu_hannah]:
    plt.plot(frame.index, frame['output'])

plt.show()

# %%
df_a_dqdt = pd.read_csv("CSV Files/a_dqdt.csv", names=["index", "output"], index_col=False, usecols = ["output"])
df_a_dqdt_hannah = pd.read_csv("300-7e-05-FullTestNew/mass_300_mix_7e-05_a_dqdt.csv", names=["index", "output"], index_col=False, usecols = ["output"])

fig = plt.figure()

for frame in [df_a_dqdt_hannah]:
    plt.plot(frame.index, frame['output'])

plt.show()


for frame in [df_a_dqdt]:
    plt.plot(frame.index, frame['output'])

plt.show()

# %% [markdown]
# ## b's

# %%
df_b_np = pd.read_csv("CSV Files/b_np.csv", names=["index", "output"], index_col=False, usecols = ["output"])
df_b_np_hannah = pd.read_csv("300-7e-05-FullTestNew/mass_300_mix_7e-05_b_np.csv", names=["index", "output"], index_col=False, usecols = ["output"])

fig = plt.figure()

for frame in [df_b_np, df_b_np_hannah]:
    plt.plot(frame.index, frame['output'])

plt.show()

# %%
df_b_pn = pd.read_csv("CSV Files/b_pn.csv", names=["index", "output"], index_col=False, usecols = ["output"])
df_b_pn_hannah = pd.read_csv("300-7e-05-FullTestNew/mass_300_mix_7e-05_b_pn.csv", names=["index", "output"], index_col=False, usecols = ["output"])

fig = plt.figure()

for frame in [df_b_pn, df_b_pn_hannah]:
    plt.plot(frame.index, frame['output'])

plt.show()

# %%
df_b_rhonu = pd.read_csv("CSV Files/b_rhonu.csv", names=["index", "output"], index_col=False, usecols = ["output"])
df_b_rhonu_hannah = pd.read_csv("300-7e-05-FullTestNew/mass_300_mix_7e-05_b_rhonu.csv", names=["index", "output"], index_col=False, usecols = ["output"])

fig = plt.figure()

for frame in [df_b_rhonu, df_b_rhonu_hannah]:
    plt.plot(frame.index, frame['output'])

plt.show()

# %%
df_b_dqdt = pd.read_csv("CSV Files/b_dqdt.csv", names=["index", "output"], index_col=False, usecols = ["output"])
df_b_dqdt_hannah = pd.read_csv("300-7e-05-FullTestNew/mass_300_mix_7e-05_b_dqdt.csv", names=["index", "output"], index_col=False, usecols = ["output"])

fig = plt.figure()

for frame in [df_b_dqdt_hannah]:
    plt.plot(frame.index, frame['output'])

plt.show()

plt.plot(df_b_dqdt.index, df_b_dqdt['output'])
plt.show()

# %% [markdown]
# ## c's

# %%
df_c_np = pd.read_csv("CSV Files/c_np.csv", names=["index", "output"], index_col=False, usecols = ["output"])
df_c_np_hannah = pd.read_csv("300-7e-05-FullTestNew/mass_300_mix_7e-05_c_np.csv", names=["index", "output"], index_col=False, usecols = ["output"])

fig = plt.figure()

for frame in [df_c_np, df_c_np_hannah]:
    plt.plot(frame.index, frame['output'])

plt.show()

# %%
df_c_pn = pd.read_csv("CSV Files/c_pn.csv", names=["index", "output"], index_col=False, usecols = ["output"])
df_c_pn_hannah = pd.read_csv("300-7e-05-FullTestNew/mass_300_mix_7e-05_c_pn.csv", names=["index", "output"], index_col=False, usecols = ["output"])

fig = plt.figure()

for frame in [df_c_pn, df_c_pn_hannah]:
    plt.plot(frame.index, frame['output'])

plt.show()

# %%
df_c_rhonu = pd.read_csv("CSV Files/c_rhonu.csv", names=["index", "output"], index_col=False, usecols = ["output"])
df_c_rhonu_hannah = pd.read_csv("300-7e-05-FullTestNew/mass_300_mix_7e-05_c_rhonu.csv", names=["index", "output"], index_col=False, usecols = ["output"])

fig = plt.figure()

for frame in [df_c_rhonu, df_c_rhonu_hannah]:
    plt.plot(frame.index, frame['output'])

plt.show()

# %%
df_c_dqdt = pd.read_csv("CSV Files/c_dqdt.csv", names=["index", "output"], index_col=False, usecols = ["output"])
df_c_dqdt_hannah = pd.read_csv("300-7e-05-FullTestNew/mass_300_mix_7e-05_c_dqdt.csv", names=["index", "output"], index_col=False, usecols = ["output"])

fig = plt.figure()


for frame in [df_c_dqdt_hannah]:
    plt.plot(frame.index, frame['output'])

plt.show()
plt.plot(df_c_dqdt.index, df_c_dqdt['output'])

#plt.xlim(0,20)
plt.show()

# %% [markdown]
# ## d's

# %%
df_d_np = pd.read_csv("CSV Files/d_np.csv", names=["index", "output"], index_col=False, usecols = ["output"])
df_d_np_hannah = pd.read_csv("300-7e-05-FullTestNew/mass_300_mix_7e-05_d_np.csv", names=["index", "output"], index_col=False, usecols = ["output"])

fig = plt.figure()

for frame in [df_d_np, df_d_np_hannah]:
    plt.plot(frame.index, frame['output'])

plt.show()

# %%
df_d_pn = pd.read_csv("CSV Files/d_pn.csv", names=["index", "output"], index_col=False, usecols = ["output"])
df_d_pn_hannah = pd.read_csv("300-7e-05-FullTestNew/mass_300_mix_7e-05_d_pn.csv", names=["index", "output"], index_col=False, usecols = ["output"])

fig = plt.figure()

for frame in [df_d_pn, df_d_pn_hannah]:
    plt.plot(frame.index, frame['output'])

plt.show()

# %%
df_d_rhonu = pd.read_csv("CSV Files/d_rhonu.csv", names=["index", "output"], index_col=False, usecols = ["output"])
df_d_rhonu_hannah = pd.read_csv("300-7e-05-FullTestNew/mass_300_mix_7e-05_d_rhonu.csv", names=["index", "output"], index_col=False, usecols = ["output"])

fig = plt.figure()

for frame in [df_d_rhonu, df_d_rhonu_hannah]:
    plt.plot(frame.index, frame['output'])

plt.show()

# %%
df_d_dqdt = pd.read_csv("CSV Files/d_dqdt.csv", names=["index", "output"], index_col=False, usecols = ["output"])
df_d_dqdt_hannah = pd.read_csv("300-7e-05-FullTestNew/mass_300_mix_7e-05_d_dqdt.csv", names=["index", "output"], index_col=False, usecols = ["output"])

fig = plt.figure()

for frame in [df_d_dqdt, df_d_dqdt_hannah]:
    plt.plot(frame.index, frame['output'])

plt.show()

# %%
ev.clean_directory('C:/Users/kathr/Chad_Research_Neutrinos/alterbbn_v2.2', 'alter_vs.c')
# Out:
# make: Circular alter_vs.c <- alter_vs.c dependency dropped.

# %%
ev.output_plots_alter_vs(1e-10, 10e-10, 40, 'C:/Users/kathr/Chad_Research_Neutrinos/alterbbn_v2.2/alter_vs.x', '255', '104.56255360706342', '300', '7e-05')
# %time
# Out:
# Wall time: 0 ns
